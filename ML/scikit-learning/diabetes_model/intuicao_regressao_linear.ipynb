# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dict_regression = {'tempo_casa': [1, 3, 6, 9, 10, 14, 18], 'salario': [1500, 3000, 4500, 6000, 7000, 8500, 10000]}

# %%
df_simple_regression = pd.DataFrame(dict_regression)

# %%
df_simple_regression.head()
# Out:
#    tempo_casa  salario
# 0           1     1500
# 1           3     3000
# 2           6     4500
# 3           9     6000
# 4          10     7000

# %%
sns.regplot(data=df_simple_regression, x="tempo_casa", y="salario")
# Out:
# <Axes: xlabel='tempo_casa', ylabel='salario'>

# %%
y = ax + b
